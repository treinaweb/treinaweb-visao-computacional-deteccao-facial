# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\rodri\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\rodri\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
import cv2 
from skimage import io, color
from IPython.display import Image
import os

# %%
Image(url = "Imagens/faces.jpg")
# Out:
# <img src="Imagens/faces.jpg"/>

# %%
img_face1 = io.imread("Imagens/faces.jpg")
io.imshow(img_face1)
io.show()

# %%
img_face1 = cv2.imread("Imagens/faces.jpg")
img_face1.shape
# Out:
# (630, 1000, 3)

# %%
img_face1_gray = color.rgb2gray(img_face1)
io.imshow(img_face1_gray)
io.show()

# %%
img_face1_gray.shape
# Out:
# (630, 1000)

# %%
grayImage1 = cv2.cvtColor(img_face1, cv2.COLOR_BGR2GRAY)
grayImage1.shape
# Out:
# (630, 1000)

# %%
face_parametro = 'Cascade/frontalface_alt.xml'

# %%
classificador_cascade = cv2.CascadeClassifier(face_parametro)

# %%
classificador_cascade
# Out:
# < cv2.CascadeClassifier 0000016222500630>

# %%
faces = classificador_cascade.detectMultiScale(grayImage1, scaleFactor=1.2, minNeighbors=10, minSize = (30, 30))

# %%
faces
# Out:
# array([[377,  36,  46,  46],
#        [847, 135,  49,  49],
#        [294, 108,  46,  46],
#        [542,  45,  44,  44],
#        [522, 113,  45,  45],
#        [616,  46,  43,  43],
#        [801, 110,  49,  49],
#        [226,  51,  47,  47],
#        [594, 114,  50,  50],
#        [ 61,  67,  49,  49],
#        [847,  25,  51,  51],
#        [411, 100,  46,  46],
#        [679,  79,  48,  48],
#        [100, 339,  52,  52],
#        [159,  48,  45,  45],
#        [312,  24,  50,  50],
#        [177, 121,  46,  46],
#        [760, 358,  49,  49],
#        [305, 359,  58,  58],
#        [640, 380,  46,  46],
#        [562, 375,  46,  46],
#        [883, 373,  54,  54],
#        [388, 381,  51,  51]])

# %%
for (x, y, width, height) in faces:
    cv2.rectangle(img_face1, (x, y), (x + width, y + height), (0, 255,0), 8)

# %%
cv2.imwrite("Imagens/faces_result.jpg", img_face1)
# Out:
# True

# %%
Image(url="Imagens/faces_result.jpg")
# Out:
# <img src="Imagens/faces_result.jpg"/>
